# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
#  Imported the dataset with: mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Reach Court Farm',
#  'AddressLine2': 'Reach Road',
#  'AddressLine3': 'St Margarets At Cliffe',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Barn',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.77622109052,
#  'FHRSID': 429982,
#  'LocalAuthorityBusinessID': 'PI/000043978',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6AQ',
#  'RatingDate': '2017-09-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65acc92cd78710fd73c206ea'),
#  'geocode': {'latitude': '51.147379', 'longitude': '1.371115'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429982',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang= {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang)

# %%
# Check that the new restaurant was inserted
results = establishments.find(penang)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65acd519b4e4edd9a683bcaf'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType':'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1, 'BusinessType':1}
results_2 = list(establishments.find(query, fields))
for result in results_2:
    print(result)
# Out:
# {'_id': ObjectId('65acc92cd78710fd73c206ea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c206fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20700'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20706'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20707'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20708'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2070c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2070f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2071a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2071c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2071e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2071f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20721'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20722'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20724'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20727'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20728'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2072b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2072f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20731'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20732'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20735'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20737'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20738'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20739'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2073a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2073c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20743'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2074c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2074e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2074f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20750'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20754'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20756'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2075c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2075e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2075f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20764'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2076c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2076d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20770'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20773'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20774'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20776'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20777'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2077a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2077d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20781'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20784'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20789'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2078c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2078e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2078f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20790'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20797'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c207fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20801'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20802'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20808'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2080e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20814'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2081b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20821'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20822'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20823'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20825'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2082a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2082d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2082f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20831'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20832'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20833'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20836'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20838'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20839'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2083a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2083c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2083e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2083f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20841'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20845'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2084e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20852'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20855'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20856'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20859'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2085e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2085f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20860'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20861'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20862'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20865'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2086a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2086d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2086e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2086f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2087d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2087e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20881'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20887'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20888'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20890'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20891'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20897'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20899'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2089b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2089e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c208e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20903'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20906'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20907'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2090e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20910'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20924'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20925'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20947'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2094b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20954'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20957'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20959'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20960'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20964'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20976'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20981'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20983'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20987'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2098a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20991'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20993'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20994'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20996'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c2099b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209c8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209d5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209f1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209f8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c209fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a20'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a42'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a49'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a59'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a5a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a61'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a67'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a6a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a77'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a79'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a7a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a82'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a8a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a94'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a95'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20a96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aa1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aa4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aa6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aaa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aaf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ab2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ab4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ab6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ab8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20abb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20abe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ac2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ac4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ac6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ac8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ad4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ad7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20adc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ade'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ae9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20af2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20af5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20af7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20aff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b57'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b6c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b74'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b76'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b7a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b80'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b88'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b8a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b8f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b91'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b94'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b95'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b9b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20b9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ba4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ba5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ba6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ba7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20baa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20baf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bb2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bbc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bbe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bbf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bc2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bc3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bcd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bd1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bd3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bdf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20be1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20be2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20be4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bf4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20bfe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c02'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c03'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c1d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c20'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c2f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c42'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c43'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c48'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c52'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c5f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c63'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c67'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c6c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c73'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c74'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c75'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c80'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c8a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20c97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ca2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ca6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ca8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ca9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cc0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cc6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ccb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ccd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cd1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cd5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cd6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cdd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ce4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ce5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20ce6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cf9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20cfd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d01'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d03'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d23'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92cd78710fd73c20d2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('65acc92ed78710fd73c2a033'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a035'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a039'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a03a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a03b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a03c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a03d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a041'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a043'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a049'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a04a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a04d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a04f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a053'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a054'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a05a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a05c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a05e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a05f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a060'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a063'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a064'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a065'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a069'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a06a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a06d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a070'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a071'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a072'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a074'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a077'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a078'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a07f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a083'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a084'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a085'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a086'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a087'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a089'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a08a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a08f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a090'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a098'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a09e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a09f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0f8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a0fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a10d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a112'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a120'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a122'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a126'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a128'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a132'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a134'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a136'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a13b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a13f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a140'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a142'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a145'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a14a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a161'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a166'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a16c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a172'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a173'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a17b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a17f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a180'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a183'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a188'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a189'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a18d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a190'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a199'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a19d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a19e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a19f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1bc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1c7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1cb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1cf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1db'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a1fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a20b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a211'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a212'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a21a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a226'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a22b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a231'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a232'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a237'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a23b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a23c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acc92ed78710fd73c2a249'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65acd519b4e4edd9a683bcaf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one({"BusinessName":"Penang Flavours"},{'$set':{'BusinessTypeID':'1'}})

# %%
# Confirm that the new restaurant was updated
results_3 = establishments.find({"BusinessName":"Penang Flavours"})
for result in results_3:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65acd519b4e4edd9a683bcaf'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName':'Dover'}
establishments.count_documents(query)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName':'Dover'})

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName':'Dover'}
establishments.count_documents(query)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('65acc92cd78710fd73c209c5'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{'$set':{'geocode.latitude':{'$toDouble':"$geocode.latitude"},
                                       'geocode.longitude':{'$toDouble':"$geocode.longitude"}
                                       }
                               }
                              ]
                          )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{'$set':{'RatingValue':{'$toInt':"$RatingValue"}}}])

# %%
# Check that the coordinates and rating value are now numbers
establishments.find_one()
# Out:
# {'_id': ObjectId('65acc92cd78710fd73c209c5'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.196408, 'latitude': 51.086058},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}
